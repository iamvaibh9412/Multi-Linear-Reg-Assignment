# %% [markdown]
# ## Name - Vaibhav R. Gudulkar

# %% [markdown]
# # Assignment - Multilinear Regression (50_Startups.csv)

# %%
#importing the libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as smf

# %%
#importing the data set
startup = pd.read_csv("50_Startups.csv")
startup.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# # EDA on dataset

# %%
#Density Plot
sns.distplot(startup['Profit'])
# Out:
# C:\Users\Vaibhav\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
#Pairplot
sns.pairplot(startup)

# %%
#Boxplot
sns.boxplot(x="State",y="Profit",data=startup)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
#Barplot
sn.barplot(x="State",y="Profit",data=startup)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
#Heatmap for better understanding of the columns relation.
sns.heatmap(startup.corr())
# Out:
# <AxesSubplot:>

# %%
X = startup.iloc[:, :-2].values

# %% [markdown]
# ### The Profit Acquired by each startup is been describe by our dependent variable i.e 'Profit'

# %%
y = startup.iloc[:, 4].values

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()

# %% [markdown]
# ### Dropping the 1st column out of our Dataset which contains one of the OneHotEncoded values.

# %%
X = X[:, 1:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Fitting Multiple Linear Regression to the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %% [markdown]
# ## Fit the created object to our training set

# %%
regressor.fit (X_train, y_train)
# Out:
# LinearRegression()

# %%
### Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [114591.30011274 107373.07340096 110454.36464285  84013.60236265
#  149100.46701714 147392.96765504  80999.89882995  94719.72395296
#  133332.969767   134987.02403535]

# %%
print(y_test)
# Out:
# [103282.38 144259.4  146121.95  77798.83 191050.39 105008.31  81229.06
#   97483.56 110352.25 166187.94]
